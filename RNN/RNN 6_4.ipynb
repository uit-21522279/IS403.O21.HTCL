# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
import warnings
import logging

# Vô hiệu hóa cảnh báo
warnings.filterwarnings("ignore")

# Thiết lập logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

def forecast_stock_prices(data, split_ratio, time_step=100):
    # Tiền xử lý dữ liệu
    data['Price'] = data['Price'].str.replace(',', '').astype(float)
    df1 = data.reset_index()['Price']

    # Chuẩn hóa dữ liệu
    scaler = MinMaxScaler(feature_range=(0, 1))
    df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

    # Chia train test
    train_size = int(len(df1) * split_ratio)
    test_size = len(df1) - train_size
    train_data, test_data = df1[0:train_size, :], df1[train_size:len(df1), :]

    # Hàm tạo dataset
    def create_dataset(dataset, time_step=1):
        dataX, dataY = [], []
        for i in range(len(dataset) - time_step - 1):
            a = dataset[i:(i + time_step), 0]
            dataX.append(a)
            dataY.append(dataset[i + time_step, 0])
        return np.array(dataX), np.array(dataY)

    # Tạo dữ liệu huấn luyện và kiểm tra
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)

    # Reshape input to be [samples, time steps, features]
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Define RNN Model
    model = Sequential()
    model.add(SimpleRNN(50, input_shape=(time_step, 1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Train the model
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)

    # Dự báo dữ liệu test
    test_predict = model.predict(X_test)

    # Chuẩn hóa ngược dữ liệu dự báo và dữ liệu thực tế
    test_predict = scaler.inverse_transform(test_predict)
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

    # Đánh giá độ chính xác
    rmse = np.sqrt(mean_squared_error(y_test, test_predict))
    mae = mean_absolute_error(y_test, test_predict)
    mape = np.mean(np.abs((y_test - test_predict) / y_test)) * 100



    # Khởi tạo hàm dự đoán
    def predict_future_days(days, model, data, input_size, scaler):
        future_predictions = []
        current_data = data.copy()
        for _ in range(days):
            x_input = current_data[-input_size:].reshape(1, -1)
            x_input = x_input.reshape((1, input_size, 1))
            yhat = model.predict(x_input, verbose=0)
            future_predictions.append(yhat[0][0])
            current_data = np.append(current_data, yhat[0][0])
        return scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

    # Dự báo tương lai
    predict_30days = predict_future_days(30, model, df1, time_step, scaler)
    predict_60days = predict_future_days(60, model, df1, time_step, scaler)
    predict_90days = predict_future_days(90, model, df1, time_step, scaler)

    # Chuẩn hóa ngược dữ liệu huấn luyện và kiểm tra
    train_data = scaler.inverse_transform(train_data)
    test_data = scaler.inverse_transform(test_data)

    # Vẽ biểu đồ
    plt.figure(figsize=(12, 6))

    # Vẽ dữ liệu huấn luyện
    plt.plot(pd.RangeIndex(start=0, stop=train_size, step=1), train_data, label='Train')

    # Vẽ dữ liệu kiểm tra
    plt.plot(pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1), test_data, label='Test')

    # Vẽ dự báo trên tập kiểm tra
    plt.plot(pd.RangeIndex(start=train_size + time_step + 1, stop=train_size + time_step + 1 + len(test_predict), step=1), test_predict, label='Predict')

    # Vẽ dự báo 90 ngày tiếp theo
    future_dates_90 = pd.RangeIndex(start=len(df1), stop=len(df1) + 90, step=1)
    plt.plot(future_dates_90, predict_90days, label='Predict 90 Days', color='purple')

    # Vẽ dự báo 60 ngày tiếp theo
    future_dates_60 = pd.RangeIndex(start=len(df1), stop=len(df1) + 60, step=1)
    plt.plot(future_dates_60, predict_60days, label='Predict 60 Days', color='brown')

    # Vẽ dự báo 30 ngày tiếp theo
    future_dates_30 = pd.RangeIndex(start=len(df1), stop=len(df1) + 30, step=1)
    plt.plot(future_dates_30, predict_30days, label='Predict 30 Days', color='red')

    plt.legend()
    plt.title('Future Price Prediction')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.grid()
    plt.show()

    print(f'Test RMSE: {rmse}')
    print(f'Test MAE: {mae}')
    print(f'Test MAPE: {mape}')

# %% [markdown]
# VIB

# %%
df = pd.read_csv('/content/VIB-Historical-Data.csv')
forecast_stock_prices(df, split_ratio=0.6)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 44ms/step - loss: 0.1855 - val_loss: 0.0856
# Epoch 2/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0134 - val_loss: 0.0268
# Epoch 3/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0097 - val_loss: 0.0522
# Epoch 4/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0040 - val_loss: 0.0117
# Epoch 5/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 6/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 7/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 8/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 9/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 10/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 11/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 12/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 13/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 14/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 15/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 16/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 17/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 18/100
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/100
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 20/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 21/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 22/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 23/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 24/100
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 25/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 26/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 27/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 28/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 29/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 30/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 31/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 32/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 33/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 34/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 35/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 36/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 37/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 38/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 39/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 40/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 41/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 42/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 43/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 44/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 45/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.8177e-04 - val_loss: 0.0015
# Epoch 46/100
# 11/11 [==============================] - 0s 22ms/step - loss: 9.8774e-04 - val_loss: 0.0013
# Epoch 47/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.6435e-04 - val_loss: 0.0012
# Epoch 48/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.5567e-04 - val_loss: 0.0010
# Epoch 49/100
# 11/11 [==============================] - 0s 25ms/step - loss: 9.8798e-04 - val_loss: 0.0014
# Epoch 50/100
# 11/11 [==============================] - 0s 22ms/step - loss: 9.8324e-04 - val_loss: 0.0017
# Epoch 51/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 52/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.6073e-04 - val_loss: 0.0013
# Epoch 53/100
# 11/11 [==============================] - 0s 26ms/step - loss: 9.1726e-04 - val_loss: 0.0015
# Epoch 54/100
# 11/11 [==============================] - 0s 22ms/step - loss: 9.1185e-04 - val_loss: 0.0010
# Epoch 55/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.3125e-04 - val_loss: 0.0010
# Epoch 56/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.7245e-04 - val_loss: 0.0015
# Epoch 57/100
# 11/11 [==============================] - 0s 25ms/step - loss: 9.7827e-04 - val_loss: 0.0016
# Epoch 58/100
# 11/11 [==============================] - 0s 22ms/step - loss: 9.0396e-04 - val_loss: 0.0014
# Epoch 59/100
# 11/11 [==============================] - 0s 22ms/step - loss: 8.6169e-04 - val_loss: 0.0015
# Epoch 60/100
# 11/11 [==============================] - 0s 24ms/step - loss: 8.7459e-04 - val_loss: 0.0012
# Epoch 61/100
# 11/11 [==============================] - 0s 28ms/step - loss: 8.6666e-04 - val_loss: 0.0012
# Epoch 62/100
# 11/11 [==============================] - 0s 25ms/step - loss: 8.6097e-04 - val_loss: 0.0015
# Epoch 63/100
# 11/11 [==============================] - 0s 25ms/step - loss: 8.6894e-04 - val_loss: 9.7053e-04
# Epoch 64/100
# 11/11 [==============================] - 0s 26ms/step - loss: 6.2671e-04 - val_loss: 5.9339e-04
# Epoch 81/100
# 11/11 [==============================] - 0s 23ms/step - loss: 5.9569e-04 - val_loss: 6.7427e-04
# Epoch 82/100
# 11/11 [==============================] - 0s 24ms/step - loss: 5.7328e-04 - val_loss: 6.4316e-04
# Epoch 83/100
# 11/11 [==============================] - 0s 24ms/step - loss: 5.7901e-04 - val_loss: 6.0851e-04
# Epoch 84/100
# 11/11 [==============================] - 0s 22ms/step - loss: 5.9483e-04 - val_loss: 6.1365e-04
# Epoch 85/100
# 11/11 [==============================] - 0s 23ms/step - loss: 6.6688e-04 - val_loss: 6.1706e-04
# Epoch 86/100
# 11/11 [==============================] - 0s 26ms/step - loss: 6.6503e-04 - val_loss: 7.8455e-04
# Epoch 87/100
# 11/11 [==============================] - 0s 25ms/step - loss: 6.5553e-04 - val_loss: 5.5927e-04
# Epoch 88/100
# 11/11 [==============================] - 0s 22ms/step - loss: 6.4904e-04 - val_loss: 8.3480e-04
# Epoch 89/100
# 11/11 [==============================] - 0s 23ms/step - loss: 6.1446e-04 - val_loss: 5.6774e-04
# Epoch 90/100
# 11/11 [==============================] - 0s 34ms/step - loss: 5.8083e-04 - val_loss: 7.0288e-04
# Epoch 91/100
# 11/11 [==============================] - 0s 42ms/step - loss: 5.8050e-04 - val_loss: 6.3018e-04
# Epoch 92/100
# 11/11 [==============================] - 0s 37ms/step - loss: 6.0990e-04 - val_loss: 6.3099e-04
# Epoch 93/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.9803e-04 - val_loss: 5.9501e-04
# Epoch 94/100
# 11/11 [==============================] - 0s 38ms/step - loss: 5.8833e-04 - val_loss: 6.2187e-04
# Epoch 95/100
# 11/11 [==============================] - 0s 43ms/step - loss: 5.9427e-04 - val_loss: 6.0095e-04
# Epoch 96/100
# 11/11 [==============================] - 0s 41ms/step - loss: 5.8848e-04 - val_loss: 6.2021e-04
# Epoch 97/100
# 11/11 [==============================] - 1s 51ms/step - loss: 5.7775e-04 - val_loss: 7.2613e-04
# Epoch 98/100
# 11/11 [==============================] - 0s 39ms/step - loss: 5.8472e-04 - val_loss: 5.8553e-04
# Epoch 99/100
# 11/11 [==============================] - 0s 22ms/step - loss: 6.1685e-04 - val_loss: 8.7633e-04
# Epoch 100/100
# 11/11 [==============================] - 0s 26ms/step - loss: 6.2128e-04 - val_loss: 5.9416e-04
# 14/14 [==============================] - 0s 10ms/step
# Test RMSE: 755.1590848695223
# Test MAE: 556.0915321691177
# Test MAPE: 1.8432499419575827

# %% [markdown]
# STB

# %%
df = pd.read_csv('/content/STB-Historical-Data.csv')
forecast_stock_prices(df, split_ratio=0.6)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 48ms/step - loss: 0.1066 - val_loss: 0.1130
# Epoch 2/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0152 - val_loss: 0.0672
# Epoch 3/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 4/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 5/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 6/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0135
# Epoch 7/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0023 - val_loss: 0.0152
# Epoch 8/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0022 - val_loss: 0.0127
# Epoch 9/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 10/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0076
# Epoch 11/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0019 - val_loss: 0.0092
# Epoch 12/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 13/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 0.0061
# Epoch 14/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 15/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 16/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 17/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 18/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 19/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 20/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 21/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 22/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 23/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 24/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 25/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 26/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 27/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 28/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 29/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 30/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 31/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 32/100
# 11/11 [==============================] - 0s 47ms/step - loss: 0.0014 - val_loss: 8.0856e-04
# Epoch 33/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 34/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 35/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0013 - val_loss: 7.0090e-04
# Epoch 36/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 8.3247e-04
# Epoch 37/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 7.9886e-04
# Epoch 38/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0013 - val_loss: 4.7666e-04
# Epoch 39/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 6.4314e-04
# Epoch 40/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 41/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0012 - val_loss: 6.2049e-04
# Epoch 42/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 4.4177e-04
# Epoch 43/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 5.2621e-04
# Epoch 44/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0011 - val_loss: 6.5288e-04
# Epoch 45/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 4.6619e-04
# Epoch 46/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 5.0341e-04
# Epoch 47/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 4.5159e-04
# Epoch 48/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 4.8481e-04
# Epoch 49/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 4.6175e-04
# Epoch 50/100
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 3.9896e-04
# Epoch 51/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 3.6514e-04
# Epoch 52/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 4.0823e-04
# Epoch 53/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 3.4671e-04
# Epoch 54/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 4.5810e-04
# Epoch 55/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0010 - val_loss: 4.2623e-04
# Epoch 56/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0010 - val_loss: 3.2772e-04
# Epoch 57/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0010 - val_loss: 3.5667e-04
# Epoch 58/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 4.1874e-04
# Epoch 59/100
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0011 - val_loss: 3.9053e-04
# Epoch 60/100
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 3.7599e-04
# Epoch 61/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 3.5242e-04
# Epoch 62/100
# 11/11 [==============================] - 0s 26ms/step - loss: 9.9115e-04 - val_loss: 3.2772e-04
# Epoch 63/100
# 11/11 [==============================] - 0s 25ms/step - loss: 9.7767e-04 - val_loss: 3.2638e-04
# Epoch 64/100
# 11/11 [==============================] - 0s 30ms/step - loss: 9.6375e-04 - val_loss: 3.2719e-04
# Epoch 65/100
# 11/11 [==============================] - 0s 25ms/step - loss: 9.8528e-04 - val_loss: 3.1097e-04
# Epoch 66/100
# 11/11 [==============================] - 0s 24ms/step - loss: 9.9229e-04 - val_loss: 3.9071e-04
# Epoch 67/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0010 - val_loss: 2.9376e-04
# Epoch 68/100
# 11/11 [==============================] - 0s 27ms/step - loss: 9.8708e-04 - val_loss: 3.0842e-04
# Epoch 69/100
# 11/11 [==============================] - 0s 30ms/step - loss: 9.5655e-04 - val_loss: 2.8866e-04
# Epoch 70/100
# 11/11 [==============================] - 0s 45ms/step - loss: 9.9687e-04 - val_loss: 2.8626e-04
# Epoch 71/100
# 11/11 [==============================] - 0s 41ms/step - loss: 9.6161e-04 - val_loss: 2.9244e-04
# Epoch 72/100
# 11/11 [==============================] - 1s 50ms/step - loss: 9.8007e-04 - val_loss: 3.0955e-04
# Epoch 73/100
# 11/11 [==============================] - 1s 51ms/step - loss: 9.2059e-04 - val_loss: 3.0078e-04
# Epoch 74/100
# 11/11 [==============================] - 0s 44ms/step - loss: 9.2105e-04 - val_loss: 2.8755e-04
# Epoch 75/100
