# %% [markdown]
# BIDV

# %%
#import thư viện cần thiết
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
# Đọc file và tiền xử lí dữ liệu
df = pd.read_csv('../data/BIDV.csv')
# Tiền xử lí dữ liệu
# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)
    
# Áp dụng hàm chuyển đổi cho cột "Vol."
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
df["Change %"] = df["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'] = df['Price'].apply(convert_str_to_number)
df['Open'] = df['Open'].apply(convert_str_to_number)
df['High'] = df['High'].apply(convert_str_to_number)
df['Low'] = df['Low'].apply(convert_str_to_number)

# %%
df1=df.reset_index()['Price']

# %%
#. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
#. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
#. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#  Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# c:\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# . Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0783
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0118
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0070
# Epoch 4/100
#  8/13 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0060

# %%
# Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Chuẩn hóa dữ liệu y_pred,ytest
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Tính RMSE
test_rmse = np.sqrt(metrics.mean_squared_error(ytest, y_pred))
print('Testing RMSE:', test_rmse)

# Tính MAPE (Mean Absolute Percentage Error)
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
print('Testing MAPE:', test_mape)

#Tinh Mae
mae = np.mean(np.abs(np.array(y_pred) - np.array(ytest)))
print('Testing Mae:', mae)
# Out:
# Testing RMSE: 1030.662097178155
# Testing MAPE: 3.471133383275735
# Testing Mae: 904.9759175755033

# %%
#. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

next_30_days = scaler.inverse_transform(lst_output_30)

# %%
#. Dự báo 60 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

next_60_days = scaler.inverse_transform(lst_output_60)

# %%
# Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

next_90_days = scaler.inverse_transform(lst_output_90)

# %%
# Vẽ hình dự báo 30 ngày tiếp theo

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+time_step+1, stop=train_size+test_size, step=1)
plt.plot(test_data_index, (y_pred))

predict_data_index_90 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,next_90_days, color='purple')
predict_data_index_60 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,next_60_days, color='red')
predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,next_30_days, color='green')
plt.legend(['Test','Predict','Predict90days', 'Predict60days', 'Predict30days'])

plt.show()

# %% [markdown]
# VIB

# %%
# Đọc file và tiền xử lí dữ liệu
df = pd.read_csv('../data/VIB.csv')
# Tiền xử lí dữ liệu
# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)
    
# Áp dụng hàm chuyển đổi cho cột "Vol."
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
df["Change %"] = df["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'] = df['Price'].apply(convert_str_to_number)
df['Open'] = df['Open'].apply(convert_str_to_number)
df['High'] = df['High'].apply(convert_str_to_number)
df['Low'] = df['Low'].apply(convert_str_to_number)

# %%
df1=df.reset_index()['Price']

# %%
#. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
#. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
#. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# c:\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# . Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.1677
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0199
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0076
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0049
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0035
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0037
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0032
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0034
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0031
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0027
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0029
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0026
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0024
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0023
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0023
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0022
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0021
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0019
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0020
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0019
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0020
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0024
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0023
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0019
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0020
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0019
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0021
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0019
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0018
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0023
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0018
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0018
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0020
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0019
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0018
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0017
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0016
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0016
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0017
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0016
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0014
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0014
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0015
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0018
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0015
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0014
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0014
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0013
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0012
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0013
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0014
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0013
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0012
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0011
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0012
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0011
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0013
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0012
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0010
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.6068e-04
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 9.7200e-04
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0011
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.1198e-04
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.5144e-04
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.0764e-04
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.6660e-04
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.4724e-04
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.4847e-04
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 7.0439e-04
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.5643e-04
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.5813e-04
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.2478e-04
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.6022e-04
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.9439e-04
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.9869e-04
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.5651e-04
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.0212e-04
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 6.8977e-04
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.8710e-04
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.3338e-04
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.5488e-04
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.0453e-04
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.4988e-04
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 6.2673e-04
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.4441e-04
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.6157e-04
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 8.5582e-04
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.2589e-04
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.4620e-04
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.3746e-04
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.9018e-04
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.5651e-04
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 6.0543e-04
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.1720e-04
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.3643e-04
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.8876e-04
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.2733e-04
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.9861e-04
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.5413e-04
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.9242e-04

# %%
#. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Chuẩn hóa dữ liệu y_pred,ytest
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Tính RMSE
test_rmse = np.sqrt(metrics.mean_squared_error(ytest, y_pred))
print('Testing RMSE:', test_rmse)

# Tính MAPE (Mean Absolute Percentage Error)
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
print('Testing MAPE:', test_mape)

#Tinh Mae
mae = np.mean(np.abs(np.array(y_pred) - np.array(ytest)))
print('Testing Mae:', mae)
# Out:
# Testing RMSE: 524.4959255246483
# Testing MAPE: 2.617043494967528
# Testing Mae: 283.7819362331081

# %%
#. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

next_30_days = scaler.inverse_transform(lst_output_30)

# %%
#. Dự báo 60 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

next_60_days = scaler.inverse_transform(lst_output_60)

# %%
# Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

next_90_days = scaler.inverse_transform(lst_output_90)

# %%
# Vẽ hình dự báo 

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+time_step+1, stop=train_size+test_size, step=1)
plt.plot(test_data_index, (y_pred))

predict_data_index_90 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,next_90_days, color='purple')
predict_data_index_60 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,next_60_days, color='red')
predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,next_30_days, color='green')
plt.legend(['Test','Predict','Predict90days', 'Predict60days', 'Predict30days'])

plt.show()

# %% [markdown]
# STB

# %%
# Đọc file và tiền xử lí dữ liệu
df = pd.read_csv('../data/STB.csv')
# Tiền xử lí dữ liệu
# Hàm chuyển đổi "Vol." từ chuỗi sang số
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)
    
# Áp dụng hàm chuyển đổi cho cột "Vol."
df["Vol."] = df["Vol."].apply(convert_volume_to_number)

# Hàm chuyển đổi "Change %" từ chuỗi sang số
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Áp dụng hàm chuyển đổi cho cột "Change %"
df["Change %"] = df["Change %"].apply(convert_change_to_number)

# Hàm chuyển giá từ chuỗi sang số
def convert_str_to_number(str):
    return float(str.replace(',', ''))

# Áp dụng hàm chuyển đổi cho các cột giá trị
df['Price'] = df['Price'].apply(convert_str_to_number)
df['Open'] = df['Open'].apply(convert_str_to_number)
df['High'] = df['High'].apply(convert_str_to_number)
df['Low'] = df['Low'].apply(convert_str_to_number)

# %%
df1=df.reset_index()['Price']

# %%
#. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
#. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
#. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# c:\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# . Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.1424
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0150
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0072
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0046
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0039
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0035
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0033
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0032
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0030
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0028
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0028
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0027
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0023
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0025
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0024
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0022
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0020
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0023
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0019
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0024
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0022
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0020
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0017
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0019
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0017
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0017
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0017
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0017
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0020
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0016
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0020
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0021
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0017
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0015
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0015
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0015
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0014
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0013
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0015
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0016
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0015
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0016
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0013
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0014
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0013
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0014
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0026
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0017
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0014
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0012
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0011
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0016
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0014
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0011
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0016
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0013
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0014
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0017
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0013
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 9.8249e-04
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0011
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0011
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 9.4349e-04
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.4806e-04
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 9.8588e-04
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.7295e-04
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0013
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0013
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0011
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.4138e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 9.0504e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0010
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 9.4561e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 8.8496e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0011
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0011
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 9.5548e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 8.1323e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.3090e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0010
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 7.6564e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 8.5352e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.8946e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 8.0774e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0010
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.6666e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 8.6134e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 9.5047e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.4744e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.5341e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0012
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0013
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0012
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 7.6201e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 8.9460e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 7.9016e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 7.1526e-04

# %%
#. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Chuẩn hóa dữ liệu y_pred,ytest
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Tính RMSE
test_rmse = np.sqrt(metrics.mean_squared_error(ytest, y_pred))
print('Testing RMSE:', test_rmse)

# Tính MAPE (Mean Absolute Percentage Error)
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
print('Testing MAPE:', test_mape)

#Tinh Mae
mae = np.mean(np.abs(np.array(y_pred) - np.array(ytest)))
print('Testing Mae:', mae)
# Out:
# Testing RMSE: 272.83104279801455
# Testing MAPE: 1.9557608549370369
# Testing Mae: 225.94729184144296

# %%
#. Dự báo 30 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_30 = []
n_steps = 100
i = 0

while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_30.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_30.extend(yhat.tolist())
        i = i + 1

next_30_days = scaler.inverse_transform(lst_output_30)

# %%
#. Dự báo 60 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_60 = []
n_steps = 100
i = 0

while i < 60:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_60.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_60.extend(yhat.tolist())
        i = i + 1

next_60_days = scaler.inverse_transform(lst_output_60)

# %%
# Dự báo 90 ngày tiếp theo
x_input = test_data[60:].reshape(1, -1)
x_input.shape

temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output_90 = []
n_steps = 100
i = 0

while i < 90:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[-100:])  # Ensure x_input has exactly 100 elements
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output_90.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = np.array(temp_input)  # Use the available elements
        x_input = x_input.reshape((1, len(temp_input), 1))  # Reshape according to the actual length
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output_90.extend(yhat.tolist())
        i = i + 1

next_90_days = scaler.inverse_transform(lst_output_90)

# %%
# Vẽ hình dự báo 

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+time_step+1, stop=train_size+test_size, step=1)
plt.plot(test_data_index, (y_pred))

predict_data_index_90 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,next_90_days, color='purple')
predict_data_index_60 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,next_60_days, color='red')
predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,next_30_days, color='green')
plt.legend(['Test','Predict','Predict90days', 'Predict60days', 'Predict30days'])

plt.show()
